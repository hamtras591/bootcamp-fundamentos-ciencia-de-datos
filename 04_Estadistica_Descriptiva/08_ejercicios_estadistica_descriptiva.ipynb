# %% [markdown]
# # Ejercicios Consolidados: Estadística Descriptiva para Analítica
#
# **Curso:** Matemáticas para Data Science: Estadística Descriptiva
# **Fecha:** Noviembre 2025
# **Módulo:** Estadística Descriptiva para Analítica
# **Repositorio:** `bootcamp-fundamentos-ciencia-de-datos`
#
# ---
#
# ## 📋 Estructura del Notebook
#
# Este notebook consolida TODOS los ejercicios del módulo en un solo lugar:
#
# 1. **Tipos de Datos** (5 ejercicios)
# 2. **Medidas de Tendencia Central** (5 ejercicios)
# 3. **Medidas de Dispersión** (5 ejercicios)
# 4. **Visualizaciones** (5 ejercicios)
# 5. **Proyecto Integrador** (1 ejercicio final)
#
# **Total:** 21 ejercicios para dominar la estadística descriptiva
#
# ---

# %% [markdown]
# ## 🛠️ Setup: Importar Librerías

# %%
# Librerías estándar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualizaciones
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 10

# Suprimir warnings
import warnings
warnings.filterwarnings('ignore')

print("✅ Librerías importadas correctamente")
print(f"Versión pandas: {pd.__version__}")
print(f"Versión numpy: {np.__version__}")

# %% [markdown]
# ## 📂 Cargar Dataset
#
# Usaremos el dataset `cars.csv` para todos los ejercicios.

# %%
# Cargar dataset
df = pd.read_csv('cars.csv')

# Exploración inicial
print(f"Dimensiones: {df.shape[0]} filas x {df.shape[1]} columnas")
print(f"\nPrimeras 3 filas:")
df.head(3)

# %% [markdown]
# ---
#
# # 1️⃣ SECCIÓN 1: Tipos de Datos
#
# **Objetivo:** Identificar y trabajar con diferentes tipos de datos en Python.
#
# ---

# %% [markdown]
# ### Ejercicio 1.1: Identificar Tipos de Datos
#
# **Enunciado:** Usa `.dtypes` para identificar los tipos de datos del DataFrame. Luego:
# 1. Cuenta cuántas variables numéricas hay
# 2. Cuenta cuántas variables categóricas (object) hay
# 3. Lista el nombre de las primeras 5 variables numéricas

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 1.2: Separar Variables por Tipo
#
# **Enunciado:** Usa `.select_dtypes()` para crear dos listas:
# 1. `vars_numericas`: todas las columnas numéricas (int64, float64)
# 2. `vars_categoricas`: todas las columnas categóricas (object)
#
# Imprime cuántas hay de cada tipo.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 1.3: Analizar Variable Categórica
#
# **Enunciado:** Selecciona la columna `'EngineType'` y:
# 1. Cuenta cuántos valores únicos tiene
# 2. Muestra la frecuencia de cada tipo de motor con `.value_counts()`
# 3. Identifica cuál es el tipo de motor más común (moda)

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 1.4: Convertir Variable a Categórica Ordinal
#
# **Enunciado:** La columna `'Condition'` tiene valores como 'New', 'Used'. Conviértela a categórica ordinal con este orden:
#
# `['Salvage', 'Fair', 'Good', 'Excellent', 'New']`
#
# **Nota:** Si tu dataset no tiene estos valores exactos, crea una columna de ejemplo.

# %%
# TU CÓDIGO AQUÍ
# Ejemplo si no existe la columna:
# df['Condition'] = np.random.choice(['New', 'Excellent', 'Good'], len(df))

# %% [markdown]
# ### Ejercicio 1.5: Validación de Tipos
#
# **Enunciado:** Crea una función `validar_tipos(df, esquema)` que:
# 1. Reciba un DataFrame y un diccionario con el esquema esperado
# 2. Verifique que cada columna tenga el tipo correcto
# 3. Retorne un diccionario con los errores encontrados
#
# Pruébala con este esquema:
# ```python
# esquema = {
#     'Price': 'int64',
#     'Mileage': 'float64',
#     'EngineType': 'object'
# }
# ```

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# # 2️⃣ SECCIÓN 2: Medidas de Tendencia Central
#
# **Objetivo:** Calcular e interpretar media, mediana y moda.
#
# ---

# %% [markdown]
# ### Ejercicio 2.1: Calcular Medidas de Tendencia Central
#
# **Enunciado:** Para la columna `'Price'`:
# 1. Calcula la media
# 2. Calcula la mediana
# 3. Calcula la moda
# 4. Compara: ¿La media y mediana son similares? ¿Qué indica esto sobre la distribución?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 2.2: Impacto de Outliers en la Media
#
# **Enunciado:** Simula el "efecto Bill Gates":
# 1. Toma una muestra de 10 precios del dataset
# 2. Calcula media y mediana
# 3. Agrega un outlier extremo (ejemplo: 1,000,000)
# 4. Recalcula media y mediana
# 5. Compara los resultados y explica qué observas

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 2.3: Tabla de Frecuencias
#
# **Enunciado:** Para la columna `'manufacturer_name'`:
# 1. Crea una tabla de frecuencias (frecuencia absoluta y relativa %)
# 2. Muestra solo los 10 fabricantes más comunes
# 3. Identifica el fabricante más común (moda)

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 2.4: Comparación Media vs Mediana por Grupo
#
# **Enunciado:** Agrupa los datos por `'EngineType'` y para cada grupo:
# 1. Calcula la media y mediana del precio
# 2. Calcula la diferencia porcentual entre media y mediana
# 3. Identifica qué tipo de motor tiene la distribución más sesgada

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 2.5: Análisis Completo de Tendencia Central
#
# **Enunciado:** Crea una función `analisis_tendencia_central(serie)` que:
# 1. Calcule media, mediana y moda
# 2. Determine si hay outliers (diferencia >15% entre media y mediana)
# 3. Recomiende cuál medida usar
# 4. Retorne un diccionario con los resultados
#
# Pruébala con las columnas `'Price'` y `'Mileage'`.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# # 3️⃣ SECCIÓN 3: Medidas de Dispersión
#
# **Objetivo:** Medir y comprender la variabilidad de los datos.
#
# ---

# %% [markdown]
# ### Ejercicio 3.1: Calcular Medidas de Dispersión
#
# **Enunciado:** Para la columna `'Price'`:
# 1. Calcula el rango
# 2. Calcula la varianza
# 3. Calcula la desviación estándar
# 4. Calcula el coeficiente de variación (CV)
# 5. Interpreta: ¿Los precios son homogéneos o heterogéneos?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 3.2: Cuartiles y Percentiles
#
# **Enunciado:** Para la columna `'Mileage'`:
# 1. Calcula Q1, Q2 (mediana) y Q3
# 2. Calcula el IQR (Rango Intercuartílico)
# 3. Calcula P10, P50, P90
# 4. Interpreta: ¿Qué kilometraje tiene el 25% de los autos con menor uso?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 3.3: Detección de Outliers con IQR
#
# **Enunciado:** Usa el método IQR para detectar outliers en `'Price'`:
# 1. Calcula Q1, Q3 e IQR
# 2. Define límite_inferior = Q1 - 1.5*IQR y límite_superior = Q3 + 1.5*IQR
# 3. Filtra los outliers
# 4. Muestra cuántos outliers hay y qué porcentaje representan
# 5. Muestra los 5 outliers más extremos

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 3.4: Comparación de Variabilidad
#
# **Enunciado:** Compara la variabilidad de `'Price'` entre diferentes tipos de motor:
# 1. Agrupa por `'EngineType'`
# 2. Calcula desviación estándar y CV para cada grupo
# 3. Identifica qué tipo de motor tiene:
#    - Mayor variabilidad absoluta (desv. estándar)
#    - Mayor variabilidad relativa (CV)
# 4. Explica la diferencia entre ambas métricas

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 3.5: Análisis Completo de Dispersión
#
# **Enunciado:** Crea una función `analisis_dispersion(serie)` que calcule y retorne:
# 1. Rango, varianza, desv. estándar, CV
# 2. Q1, Q2, Q3, IQR
# 3. Número y porcentaje de outliers
# 4. Una interpretación de la variabilidad (Baja < 15%, Moderada 15-30%, Alta >30%)
#
# Pruébala con `'Price'` y `'EngineVolume'`.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# # 4️⃣ SECCIÓN 4: Visualizaciones
#
# **Objetivo:** Crear visualizaciones efectivas para comunicar insights.
#
# ---

# %% [markdown]
# ### Ejercicio 4.1: Histograma de Distribución
#
# **Enunciado:** Crea un histograma de `'Price'` que muestre:
# 1. La distribución con 30 bins
# 2. Una curva KDE superpuesta
# 3. Título, etiquetas de ejes y grid
# 4. Interpreta: ¿La distribución es simétrica o sesgada?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 4.2: Box Plot Comparativo
#
# **Enunciado:** Crea un box plot que compare `'Price'` entre diferentes `'EngineType'`:
# 1. Usa colores distintos para cada tipo
# 2. Ordena los tipos de mayor a menor mediana
# 3. Identifica visualmente qué tipo tiene más outliers
# 4. ¿Qué tipo de motor tiene mayor dispersión?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 4.3: Scatter Plot con Correlación
#
# **Enunciado:** Crea un diagrama de dispersión que muestre:
# 1. La relación entre `'EngineVolume'` (eje X) y `'Price'` (eje Y)
# 2. Colores diferentes por `'EngineType'`
# 3. Calcula e imprime la correlación entre ambas variables
# 4. Interpreta: ¿Mayor volumen de motor significa mayor precio?

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 4.4: Diagrama de Barras Top 10
#
# **Enunciado:** Crea un diagrama de barras que muestre:
# 1. Los 10 fabricantes con más autos en el dataset
# 2. Barras horizontales ordenadas de mayor a menor
# 3. Porcentaje que representa cada uno del total
# 4. Título descriptivo y etiquetas claras

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 4.5: Dashboard de Visualizaciones
#
# **Enunciado:** Crea un dashboard con 4 subplots (2x2) que muestre:
# 1. **Subplot 1:** Histograma de `'Price'`
# 2. **Subplot 2:** Box plot de `'Price'` por `'EngineType'`
# 3. **Subplot 3:** Scatter plot `'Mileage'` vs `'Price'`
# 4. **Subplot 4:** Top 5 fabricantes (barras)
#
# Usa `plt.subplots(2, 2, figsize=(15, 12))`

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# # 🏆 PROYECTO INTEGRADOR FINAL
#
# **Objetivo:** Aplicar TODOS los conceptos aprendidos en un análisis completo.
#
# ---

# %% [markdown]
# ## Proyecto: Análisis Completo del Mercado de Autos Usados
#
# **Contexto:** Eres un analista de datos contratado por una empresa de compra-venta de autos usados. Tu tarea es generar un **reporte ejecutivo completo** que incluya:
#
# ### PARTE 1: Identificación y Validación de Datos (10 pts)
# 1. Identifica tipos de datos
# 2. Reporta valores nulos y duplicados
# 3. Identifica variables categóricas vs numéricas
#
# ### PARTE 2: Análisis de Tendencia Central (20 pts)
# 4. Calcula media, mediana y moda del precio
# 5. Analiza si hay sesgo en la distribución
# 6. Determina el "precio típico" (justifica si usas media o mediana)
#
# ### PARTE 3: Análisis de Dispersión (20 pts)
# 7. Calcula todas las medidas de dispersión del precio
# 8. Detecta outliers usando método IQR
# 9. Compara variabilidad entre tipos de motor
#
# ### PARTE 4: Visualizaciones (30 pts)
# 10. Crea un dashboard con 6 visualizaciones:
#     - Distribución de precios (histograma)
#     - Outliers en precios (box plot)
#     - Precio vs Kilometraje (scatter)
#     - Precios por tipo de motor (box plot comparativo)
#     - Top 10 fabricantes (barras)
#     - Matriz de correlación (heatmap)
#
# ### PARTE 5: Insights y Recomendaciones (20 pts)
# 11. Escribe 5 insights clave que descubriste
# 12. Da 3 recomendaciones de negocio basadas en datos
# 13. Identifica qué tipo de autos son mejores inversiones
#
# ---
#
# ### Criterios de Evaluación:
#
# - **Corrección técnica:** Cálculos correctos
# - **Calidad de código:** Limpio, comentado, organizado
# - **Visualizaciones:** Claras, etiquetadas, informativas
# - **Interpretación:** Insights relevantes y bien justificados
# - **Presentación:** Reporte profesional y completo
#
# ---

# %% [markdown]
# ### PARTE 1: Identificación y Validación de Datos

# %%
# TU CÓDIGO AQUÍ PARA PARTE 1

# %% [markdown]
# ### PARTE 2: Análisis de Tendencia Central

# %%
# TU CÓDIGO AQUÍ PARA PARTE 2

# %% [markdown]
# ### PARTE 3: Análisis de Dispersión

# %%
# TU CÓDIGO AQUÍ PARA PARTE 3

# %% [markdown]
# ### PARTE 4: Visualizaciones

# %%
# TU CÓDIGO AQUÍ PARA PARTE 4

# %% [markdown]
# ### PARTE 5: Insights y Recomendaciones

# %% [markdown]
# **TUS INSIGHTS Y RECOMENDACIONES AQUÍ:**
#
# #### 📊 Insights Clave:
# 1. [Tu insight 1]
# 2. [Tu insight 2]
# 3. [Tu insight 3]
# 4. [Tu insight 4]
# 5. [Tu insight 5]
#
# #### 💡 Recomendaciones de Negocio:
# 1. [Tu recomendación 1]
# 2. [Tu recomendación 2]
# 3. [Tu recomendación 3]
#
# #### 🎯 Mejores Inversiones:
# [Tu análisis de qué autos son mejores inversiones y por qué]

# %% [markdown]
# ---
#
# # 🎓 ¡Felicitaciones!
#
# Has completado todos los ejercicios del módulo de **Estadística Descriptiva para Analítica**.
#
# ## 📚 Conceptos Dominados:
#
# ✅ **Tipos de Datos:** Categóricos (nominales/ordinales) y Numéricos (discretos/continuos)
# ✅ **Tendencia Central:** Media, Mediana, Moda
# ✅ **Dispersión:** Rango, Varianza, Desv. Estándar, CV, IQR
# ✅ **Outliers:** Detección y manejo
# ✅ **Visualizaciones:** Histogramas, Box Plots, Scatter Plots, Dashboards
#
# ## 🚀 Próximos Pasos:
#
# 1. Aplica estos conceptos a tus propios datasets
# 2. Continúa con el siguiente módulo del curso
# 3. Construye un portafolio de análisis de datos
#
# ---
#
# **Actualizado:** Noviembre 2025
# **Repositorio:** `bootcamp-fundamentos-ciencia-de-datos`
